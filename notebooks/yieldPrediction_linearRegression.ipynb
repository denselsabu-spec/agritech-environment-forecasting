# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#load cleaned dataset
df = pd.read_csv("../data/mushroom_yield_cleaned.csv")

# %%
#select the input and output features
X = df[[
    "temperature_c",
    "humidity_percent",
    "co2_ppm"
]]

y = df["yield_kg"]

# %%
#scaling the features using min max
scaler = MinMaxScaler()

X_scaled = scaler.fit_transform(X)

# %%
#spliting dataset
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
#lenear regression
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#make prediction
y_pred = model.predict(X_test)

# %%
#calculate mean squared error
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 89.49525799038

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)

print("R2 Score:", r2)
# Out:
# R2 Score: -0.013723711599954669

# %%
#to check actual yield vd predited yield
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))

sns.scatterplot(
    x=y_test,
    y=y_pred
)

# Perfect prediction reference line
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color='red'
)

plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.title("Actual vs Predicted Yield (Linear Regression)")

plt.show()
